# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
#Cleaning the data
file = pd.read_csv('PCspecs - Sheet1.csv')
file.head()
# Out:
#                                         Laptop Price (ZAR)  Screen size (")  \
# 0                          ASUS E402NA Celeron    4,599.00             14.0
# 1                          ASUS E402NA Pentium    4,899.00             14.0
# 2                   ASUS F541SA-GQ558T Celeron    3,999.00             15.6
# 3  ASUS UX370UN-CV172R 8th Gen i7 Zenbook Blue   18,999.00             14.0
# 4                         Acer A315-51-3327 i3    6,499.00             15.6
#
#                           Processor       RAM Hard drive Optical drive  \
# 0  Intel Celeron N3350 up to 2.4GHz  4GB DDR4     1000GB             N
# 1     Intel Quad-Core Pentium N4200  4GB DDR4     1000GB             N
# 2              Intel Celeron N3060   4GB DDR3      500GB             Y
# 3    Intel Core i7 8550u up to 4GHz  4GB DDR3  256GB SSD             N
# 4        Intel Core i3 7020U 2.3GHz   4GB DDR     1000GB             N
#
#         Operating system  Battery cells
# 0  Windows 10 Home 64bit              2
# ...

# %%
#Sorting Phase
#Max recommender Higher price computer

file

high_pc = file[file['Price (ZAR)'] == file['Price (ZAR)'].max()]
#type(test)

high_pc

#Size

size = file[file['Screen size (")'] == file['Screen size (")'].max()]
size

#Battery

battery = file[file['Battery cells'] == file['Battery cells'].max()]
battery
# Out:
#                           Laptop Price (ZAR)  Screen size (")  \
# 5           Acer A515-51-58D3 i5    7,999.00             15.6
# 6     DELL Inspiron 3552 Celeron    4,599.00             15.6
# 7          DELL Inspiron 3567 i3    5,999.00             15.6
# 8  DELL Inspiron 3567 i5 7th Gen    7,999.00             15.6
#
#                            Processor       RAM Hard drive  Battery cells
# 5  Intel Core i5-7200U up to 3.10GHz  4GB DDR4     1000GB              4
# 6  Intel Celeron N3060 up to 2.48GHz   4GB DDR      500GB              4
# 7           Intel Core i3 6006U 2GHz  4GB DDR       500GB              4
# 8   Intel Core i5 7200U up to 3.1GHz   4GB DDR     1000GB              4

# %%
#Sorting Phase
#Max recommender Higher price computer

file

high_pc = file[file['Price (ZAR)'] == file['Price (ZAR)'].min()]
#type(test)

high_pc

#Size

size = file[file['Screen size (")'] == file['Screen size (")'].min()]
size

#Battery

battery = file[file['Battery cells'] == file['Battery cells'].min()]
battery
# Out:
#                         Laptop Price (ZAR)  Screen size (")  \
# 0          ASUS E402NA Celeron    4,599.00             14.0
# 1          ASUS E402NA Pentium    4,899.00             14.0
# 4         Acer A315-51-3327 i3    6,499.00             15.6
# 11  Lenovo Ideapad 110 Celeron    4,099.00             15.6
#
#                             Processor          RAM Hard drive  Battery cells
# 0    Intel Celeron N3350 up to 2.4GHz     4GB DDR4     1000GB              2
# 1       Intel Quad-Core Pentium N4200     4GB DDR4     1000GB              2
# 4          Intel Core i3 7020U 2.3GHz      4GB DDR     1000GB              2
# 11  Intel Celeron N3060 up to 2.48GHz  4GB DDR RAM      500GB              2

# %%
file
# Out:
#                                          Laptop Price (ZAR)  Screen size (")  \
# 0                           ASUS E402NA Celeron    4,599.00             14.0
# 1                           ASUS E402NA Pentium    4,899.00             14.0
# 2                    ASUS F541SA-GQ558T Celeron    3,999.00             15.6
# 3   ASUS UX370UN-CV172R 8th Gen i7 Zenbook Blue   18,999.00             14.0
# 4                          Acer A315-51-3327 i3    6,499.00             15.6
# 5                          Acer A515-51-58D3 i5    7,999.00             15.6
# 6                    DELL Inspiron 3552 Celeron    4,599.00             15.6
# 7                         DELL Inspiron 3567 i3    5,999.00             15.6
# 8                 DELL Inspiron 3567 i5 7th Gen    7,999.00             15.6
# 9                   HP 15- bs004ni i5 (1ZD14EA)    7,899.00             15.6
# 10         HP Pavillion 15-bc301ni i5 (2PQ21EA)   11,999.00             15.6
# ...
